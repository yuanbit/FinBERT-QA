# %%
# !rm -r fiqa

# %%
# !git clone https://github.com/yuanbit/fiqa.git
# Out:
# Cloning into 'fiqa'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 520 (delta 93), reused 84 (delta 44), pack-reused 374
# Receiving objects: 100% (520/520), 176.74 MiB | 12.78 MiB/s, done.
# Resolving deltas: 100% (241/241), done.
# Checking out files: 100% (51/51), done.

# %%
from fiqa.src.qa_lstm import *

# %%
config = {
    'model_type': "qa_lstm",
    'emb_dim': 100,
    'hidden_size': 256,
    'dropout': 0.2,
    'max_seq_len': 128,
    'batch_size': 64,
    'n_epochs': 1,
    'learning_rate': 0.001,
    'device': 'gpu',
}

# %%
train_qa_lstm_model(config)
# Out:
# ...
#   0%|          | 0/5676 [00:00<?, ?it/s]
# 50456 words are found in GloVe
#
#
# Generating training data...
# ...
# 100%|██████████| 5676/5676 [00:19<00:00, 285.92it/s]
#
# ...
#   6%|▌         | 37/631 [00:00<00:01, 369.40it/s]
# Generating validation data...
# ...
# 100%|██████████| 631/631 [00:03<00:00, 207.01it/s]
#
# ...
#   0%|          | 1/4342 [00:00<07:29,  9.66it/s]
# Training model...
# ...
#  34%|███▍      | 1485/4342 [02:04<04:04, 11.66it/s]
# ...
# ...
# 100%|██████████| 4342/4342 [06:03<00:00, 11.93it/s]
# Validating...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9d02af11bd3d> in <module>()
# ----> 1 train_qa_lstm_model(config)
#
# /content/fiqa/src/qa_lstm.py in __init__(self, config)
#     101             # Evaluate validation loss
#     102             print("Validating...\n")
# --> 103             valid_loss = self.validate(model, validation_dataloader)
#     104
# ...
